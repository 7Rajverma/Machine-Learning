# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr =  LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
from sklearn.linear_model import Ridge

# %%
r = Ridge(alpha=10)
r.fit(X,y)
print(r.coef_)
print(r.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235726

# %%
r1 = Ridge(alpha=100)
r1.fit(X,y)
print(r1.coef_)
print(r1.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033308

# %%
plt.plot(X,y,'b+')
plt.plot(X,lr.predict(X),color='red',label='alpha=0')
plt.plot(X,r.predict(X),color='green',label='alpha=10')
plt.plot(X,r1.predict(X),color='yellow',label='alpha=100')
plt.legend()

# %%
class meraRidge():
    def __init__(self,alpha):
        self.alpha = alpha
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):

        # for m 
        nume = 0
        deno = 0
        for i in range(X_train.shape[0]):
            nume = nume + (y_train[i] - y_train.mean())*(X_train[i] - X_train.mean())
            deno = deno + (X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()) 
        self.m = nume/(deno + self.alpha)

        # for b
        
        self.b = y_train.mean() - self.m*(X_train.mean())
        print(self.m,self.b)

    def predict(self,X_test):
        pass

# %%
rrr = meraRidge(alpha=10)

# %%
rrr.fit(X,y)
# Out:
# [24.9546267] [-2.126913]
